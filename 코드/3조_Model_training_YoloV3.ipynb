# %% [markdown]
# **Connect google drive**

# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# Wed Nov 24 07:34:34 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **1) Clone the Darknet**

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15368, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 15368 (delta 0), reused 1 (delta 0), pack-reused 15367
# Receiving objects: 100% (15368/15368), 13.98 MiB | 9.01 MiB/s, done.
# Resolving deltas: 100% (10335/10335), done.

# %% [markdown]
# **2) Compile Darknet using Nvidia GPU**

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make
# Out:
# /content/darknet
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %% [markdown]
# **3) Configure Darknet network for training YOLO V3**

# %%
#!cp cfg/yolov3.cfg cfg/yolov3_training.cfg
# !cp /content/gdrive/MyDrive/yolov3/data/yolov3_testing.cfg cfg/yolov3_training.cfg
# !cp /mydrive/yolov3/data/yolov3_testing.cfg cfg/yolov3_training.cfg

# %%
# !echo -e '' > data/obj.names
# !echo -e '' > data/obj.data
# !cp /mydrive/yolov3/data/obj.names data/obj.names
# !cp /mydrive/yolov3/data/obj.data data/obj.data
# !mkdir data/obj

# %%
# Download weights darknet model 53
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-11-24 07:36:09--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  23.3MB/s    in 7.3s
#
# 2021-11-24 07:36:17 (21.1 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# **4) Extract Images**
#
# The images need to be inside a zip archive called "images.zip" and they need to be inside the folder "yolov3" on Google Drive

# %%
# !unzip /mydrive/최종프로젝트/자료/final/vest.zip -d data/obj
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: data/obj/vest/S2-N1802M13789.jpg
#   inflating: data/obj/vest/S2-N1802M13789.txt
#  extracting: data/obj/vest/S2-N1802M13790.jpg
#   inflating: data/obj/vest/S2-N1802M13790.txt
#  extracting: data/obj/vest/S2-N1802M13792.jpg
#  extracting: data/obj/vest/S2-N1802M13792.txt
#  extracting: data/obj/vest/S2-N1802M13793.jpg
#  extracting: data/obj/vest/S2-N1802M13793.txt
#   inflating: data/obj/vest/S2-N1802M13873.jpg
#   inflating: data/obj/vest/S2-N1802M13873.txt
#   inflating: data/obj/vest/S2-N1802M13875.jpg
#   inflating: data/obj/vest/S2-N1802M13875.txt
#   inflating: data/obj/vest/S2-N1802M13876.jpg
#   inflating: data/obj/vest/S2-N1802M13876.txt
#  extracting: data/obj/vest/S2-N1802M13980.jpg
#   inflating: data/obj/vest/S2-N1802M13980.txt
#  extracting: data/obj/vest/S2-N1802M13981.jpg
#   inflating: data/obj/vest/S2-N1802M13981.txt
#  extracting: data/obj/vest/S2-N1802M13982.jpg
#   inflating: data/obj/vest/S2-N1802M13982.txt
# ...

# %%
import glob
images_list = sorted(glob.glob("data/obj/*.jpg"))
#images_list = glob.glob("data/obj/*.png")
# print(images_list)

# %%
#Create testing.txt file
file = open("data/test.txt", "w") 
file.write("\n".join(images_list[-26:])) 
file.close()

# %%
#Create training.txt file
file = open("data/train.txt", "w") 
file.write("\n".join(images_list[:-26])) 
file.close()

# %% [markdown]
# **5) Start the training**

# %%
# Start the training
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# yolov3_training
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 8, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...

# %%
# kick off training from where it last saved
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg /mydrive/yolov3/yolov3_training_final.weights -dont_show
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# yolov3_training
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 8, batch = 8, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...

# %%
# https://keyog.tistory.com/44
# !git clone https://github.com/Cartucho/mAP
# Out:
# Cloning into 'mAP'...
# remote: Enumerating objects: 908, done.
# remote: Total 908 (delta 0), reused 0 (delta 0), pack-reused 908
# Receiving objects: 100% (908/908), 14.71 MiB | 40.60 MiB/s, done.
# Resolving deltas: 100% (321/321), done.

# %%
# test, mAP 확인
# !./darknet detector map data/obj.data cfg/yolov3_training.cfg /mydrive/yolov3/yolov3_training_final.weights
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...
